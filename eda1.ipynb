# %%
# comment
# observation

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv(r"D:\full_stack\MyPractice\statistics\data\student.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.size
# Out:
# 8000

# %%
df.info()
# segrating the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df["gender"].dtype
# Out:
# dtype('O')

# %%
df["gender"].dtype=="O"
# Out:
# True

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
# segrating the data
# numeric amd categorical

# %%
for i in df.columns:    
    print(i,"---->",df[i].dtype)
# Out:
# gender ----> object
# race/ethnicity ----> object
# parental level of education ----> object
# lunch ----> object
# test preparation course ----> object
# math score ----> int64
# reading score ----> int64
# writing score ----> int64

# %%
num_col=[fea for fea in df.columns if df[fea].dtype !="O"]

# %%
cat_col=[fea for fea in df.columns if df[fea].dtype =="O"]

# %%
df[num_col]
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
df[cat_col]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course
# 0                      none
# 1                 completed
# 2                      none
# ...

# %%
df.memory_usage()
# Out:
# Index                           128
# gender                         8000
# race/ethnicity                 8000
# parental level of education    8000
# lunch                          8000
# test preparation course        8000
# math score                     8000
# reading score                  8000
# writing score                  8000
# dtype: int64

# %% [markdown]
# # missing value

# %%
df.isnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # dublicate

# %%
df.duplicated()
# checking all the columns
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # unique values

# %%
df.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
df["gender"].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %% [markdown]
# # statistical analysis

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.describe().T
# Out:
#                 count    mean        std   min    25%   50%   75%    max
# math score     1000.0  66.089  15.163080   0.0  57.00  66.0  77.0  100.0
# reading score  1000.0  69.169  14.600192  17.0  59.00  70.0  79.0  100.0
# writing score  1000.0  68.054  15.195657  10.0  57.75  69.0  79.0  100.0

# %%
# min  25%-50%-75%-max   are the despersion of the data  (IOR-->75--25)

# %% [markdown]
# # corelation

# %%
df.corr()
#conclusin --> if we are goog reader then we are a good writer
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
df.cov()
#covarience
# Out:
#                math score  reading score  writing score
# math score     229.918998     180.998958     184.939133
# reading score  180.998958     213.165605     211.786661
# writing score  184.939133     211.786661     230.907992

# %%
df.skew()
# left skewed as it is negative
# Out:
# math score      -0.278935
# reading score   -0.259105
# writing score   -0.289444
# dtype: float64

# %%
sns.displot(df['math score'])

# %%
sns.displot(df['math score'],kde = True)

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
# average
average=(df["math score"]+df["reading score"]+df["writing score"])/3

# %%
average
# Out:
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333
#          ...
# 995    94.000000
# 996    57.333333
# 997    65.000000
# 998    74.333333
# 999    83.000000
# Length: 1000, dtype: float64

# %%
# aving new column to our data set
df["Averge"]=(df["math score"]+df["reading score"]+df["writing score"])/3

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# # group by operation

# %%
df.groupby("gender").mean()
# Out:
#         math score  reading score  writing score     Averge
# gender
# female   63.633205      72.608108      72.467181  69.569498
# male     68.728216      65.473029      63.311203  65.837483

# %%
df.groupby("gender").count()
# Out:
#         race/ethnicity  parental level of education  lunch  \
# gender
# female             518                          518    518
# male               482                          482    482
#
#         test preparation course  math score  reading score  writing score  \
# gender
# female                      518         518            518            518
# male                        482         482            482            482
#
#         Averge
# gender
# female     518
# male       482

# %%
# question : find number of student less than 30 marks in maths
df[df["math score"]<30]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 17   female        group B            some high school  free/reduced
# 59   female        group C            some high school  free/reduced
# 91     male        group C                 high school  free/reduced
# 145  female        group C                some college  free/reduced
# 327    male        group A                some college  free/reduced
# 338  female        group B            some high school  free/reduced
# 363  female        group D            some high school  free/reduced
# 466  female        group D          associate's degree  free/reduced
# 528  female        group D           bachelor's degree  free/reduced
# 601  female        group C                 high school      standard
# 683  female        group C            some high school  free/reduced
# 787  female        group B                some college      standard
# 842  female        group B                 high school  free/reduced
# ...

# %%
df[df["math score"]<30].count()
# Out:
# gender                         14
# race/ethnicity                 14
# parental level of education    14
# lunch                          14
# test preparation course        14
# math score                     14
# reading score                  14
# writing score                  14
# Averge                         14
# dtype: int64

# %% [markdown]
# # scipy library is for stats

# %%
p value
# for particular column
# we have to do for all values

# %%
if p >0.05 # threshold {general}
then my data will be normal distributed

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'Averge'],
#       dtype='object')

# %%
df[num_col]
# Out:
#    math score  reading score  writing score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
from scipy.stats import normaltest

# %%
normaltest(df[num_col]["math score"])
# Out:
# NormaltestResult(statistic=15.408960513931822, pvalue=0.00045080293869937836)

# %%
normaltest(df[num_col]["math score"])[1]
# Out:
# 0.00045080293869937836

# %%
normaltest(df[num_col]["math score"])[1]*100
# Out:
# 0.04508029386993784

# %%
sns.distplot(df[num_col]["math score"])
# Out:
# <AxesSubplot:xlabel='math score', ylabel='Density'>

# %% [markdown]
# # outliers

# %%
# with respect to IQR

# %%
'''lower_fence=percentile_25-1.5*(IQR)
higher_fence=percentile_75+1.5*(IQR)'''

# %%
sns.distplot(df[num_col]["math score"])
# Out:
# <AxesSubplot:xlabel='math score', ylabel='Density'>

# %%
sns.boxplot(data=df['math score'])
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df[num_col]['reading score'])
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='Density'>

# %%
sns.boxplot(data=df['reading score'])
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df[num_col]['writing score'])
# Out:
# <AxesSubplot:xlabel='writing score', ylabel='Density'>

# %%
sns.boxplot(data=df['writing score'])
# Out:
# <AxesSubplot:>

# %%
df["math score"].quantile(0.10) # 10 percentile of data
# only 47 points will be there
# Out:
# 47.0

# %%
df["math score"].quantile(0.90) # 90 percentile of data
# only 86 points will be there
# Out:
# 86.0

# %%
df["math score"].quantile(1)# 100 percentile of data
# Out:
# 100.0

# %%
df["math score"].min()
# full points
# Out:
# 0

# %%
df["math score"].max()
# Out:
# 100

# %%
df["math score"].unique()
# Out:
# array([ 72,  69,  90,  47,  76,  71,  88,  40,  64,  38,  58,  65,  78,
#         50,  18,  46,  54,  66,  44,  74,  73,  67,  70,  62,  63,  56,
#         97,  81,  75,  57,  55,  53,  59,  82,  77,  33,  52,   0,  79,
#         39,  45,  60,  61,  41,  49,  30,  80,  42,  27,  43,  68,  85,
#         98,  87,  51,  99,  84,  91,  83,  89,  22, 100,  96,  94,  48,
#         35,  34,  86,  92,  37,  28,  24,  26,  95,  36,  29,  32,  93,
#         19,  23,   8], dtype=int64)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
q1=df["math score"].quantile(0.10)
q3=df["math score"].quantile(0.90)
#q1=df["math score"].quantile(0.25)
#q3=df["math score"].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower_limit=q1-1.5*(IQR)
higher_limit=q3+1.5*(IQR)

# %%
print(higher_limit)
# Out:
# 144.5

# %%
print(lower_limit)
# Out:
# -11.5

# %%
df[df["math score"]<lower_limit]
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score, Averge]
# Index: []

# %%
df[df["math score"]>higher_limit]
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score, Averge]
# Index: []

# %%
# so we reduce the value of q1 and q3 so we can trim the data

# %%
q1=df["math score"].quantile(0.25)
q3=df["math score"].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower_limit=q1-1.5*(IQR)
higher_limit=q3+1.5*(IQR)

# %%
lower_limit
# Out:
# 27.0

# %%
higher_limit
# Out:
# 107.0

# %%
df[df["math score"]<lower_limit] # outliers
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 17   female        group B            some high school  free/reduced
# 59   female        group C            some high school  free/reduced
# 145  female        group C                some college  free/reduced
# 338  female        group B            some high school  free/reduced
# 466  female        group D          associate's degree  free/reduced
# 787  female        group B                some college      standard
# 842  female        group B                 high school  free/reduced
# 980  female        group B                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 17                     none          18             32             28
# 59                     none           0             17             10
# 145                    none          22             39             33
# ...

# %%
df[df["math score"]>higher_limit]
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score, Averge]
# Index: []

# %%
sns.boxplot(data=df['math score'])
# Out:
# <AxesSubplot:>

# %%
# so we can drop it or we can use iloc

# %%
df_num=df[num_col]

# %%
def outlier_threshold(df,variable):
    q1=df[variable].quantile(0.25)
    q2=df[variable].quantile(0.75)
    iqr=q2-q1
    up_limit=q2+(1.5*iqr)
    lower_limit=q1-(1.5*iqr)
    return lower_limit,up_limit

# %%
def replace_with_threshold(data,numeric_col):
    for variable in numeric_col:
        low_limit,upper_limit=outlier_threshold(data,variable)
        data.loc[data[variable]<low_limit,variable]=low_limit
        data.loc[data[variable]>upper_limit,variable]=upper_limit

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num_col
# Out:
# ['math score', 'reading score', 'writing score']

# %%
replace_with_threshold(df_num,df_num.columns)
# Out:
# (27.0, 107.0)

# %%
# Out:
#   Input In [225]
#     low_limit,upper_limit=outlier_threshold(data_num,variable)
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# # graphical analysis

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score     Averge
# 0                    none          72             72             74  72.666667
# 1               completed          69             90             88  82.333333
# 2                    none          90             95             93  92.666667
# 3                    none          47             57             44  49.333333
# 4                    none          76             78             75  76.333333

# %%
sns.countplot(df["gender"])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.countplot(df["race/ethnicity"])
#univarate analysis
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='count'>

# %%
df.groupby("gender").mean()
# Out:
#         math score  reading score  writing score     Averge
# gender
# female   63.633205      72.608108      72.467181  69.569498
# male     68.728216      65.473029      63.311203  65.837483

# %%
data1=df.groupby("gender").mean()

# %%
data1["Averge"]
# Out:
# gender
# female    69.569498
# male      65.837483
# Name: Averge, dtype: float64

# %%
data1["math score"]
# Out:
# gender
# female    63.633205
# male      68.728216
# Name: math score, dtype: float64

# %%
# plot  ---?
plt.figure(figsize=(10,10))
x=['Total avg','math avg']
female_score=data1["Averge"][0],data1['math score'][0]
male_score=data1["Averge"][1],data1['math score'][1]

# %%
female_score
# Out:
# (69.56949806949807, 63.633204633204635)

# %%
male_score
# Out:
# (65.8374827109267, 68.72821576763485)

# %%
plt.figure(figsize=(10,10))
X=['Total avg','math avg']
female_score=df['Averge'][0],df['math score'][0]
male_score=df['Averge'][1],df['math score'][1]
X_axis=np.arange(len(X))
plt.bar(X_axis-0.2,male_score,0.4,label='male')
plt.bar(X_axis+0.2,female_score,0.4,label='female')

plt.xticks(X_axis,X)
plt.ylabel("marks")
plt.title("total avg vs math avg",fontweight='bold')
plt.legend()
plt.show()

# %%
df_num.corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
sns.heatmap(df_num.corr(),annot=True,cmap='icefire',linewidths=0.3)
fig=plt.gcf()
fig.set_size_inches(15,10)
plt.title("corr between variable",color='black',size=25)
plt.show()

# %%
sns.pairplot(df)

# %%
sns.violinplot(data=df_num, x=df_num["math score"], y=df_num["writing score"], hue=None)
# Out:
# <AxesSubplot:xlabel='math score', ylabel='writing score'>

# %%
sns.violinplot(data=df_num,)
# here we can also check the outlier
# Out:
# <AxesSubplot:>

# %%
10 dataset

pick anyone

perform detail EDA in one ipynb
perform missing value handle if it is there in one ipynb all the method(10-12)
perform outlier handle if it is there in one ipynb all the method(10-12)
perform encoding  if it is required in one ipynb all the method(10-12)
perform scaling one ipynb all the method(10-12)
perform feature selection in one ipynb all the method(10-12)
perform transformation one ipynb all the method(10-12)

book, different artical,research paper

friday till 12AM ist

sunny.savita@ineuron.ai
krish.naik@ineuron.ai

all 10 dataset you can solve it you can keep those solution in gitgub
